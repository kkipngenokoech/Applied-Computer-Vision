# %% [markdown]
# # OPEN CV 101

# %% [markdown]
# ## Importing CV

# %%
import cv2

# %% [markdown]
# ## Reading & displaying images

# %%
# read the image
image = cv2.imread("path to the image")
# show the image
cv2.imshow("Image", image)
